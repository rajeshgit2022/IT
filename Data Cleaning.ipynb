# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({ "Age":
[15,18, "18",19.4, "20+"], "Gender": ["male", "female", "female", "female", "male"]})
df
# Out:
#     Age  Gender
# 0    15    male
# 1    18  female
# 2    18  female
# 3  19.4  female
# 4   20+    male

# %%
df.info() # Age shld be int or float but it is in object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     5 non-null      object
#  1   Gender  5 non-null      object
# dtypes: object(2)
# memory usage: 212.0+ bytes

# %%
df["Age"].unique()  #'18' and '20+' are sting
# Out:
# array([15, 18, '18', 19.4, '20+'], dtype=object)

# %% [markdown]
# 1. Wrong data
# ⚫ Solution: Replace

# %%
df["Age"] = df [ "Age"].replace({"20+":20})
df
# Out:
#     Age  Gender
# 0    15    male
# 1    18  female
# 2    18  female
# 3  19.4  female
# 4    20    male

# %%
df["Age"] = df [ "Age"].replace({"20":25,"18":18})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 2  18.0  female
# 3  19.4  female
# 4  20.0    male

# %%
df.dtypes
# Out:
# Age       float64
# Gender     object
# dtype: object

# %%
df["Age"] = df["Age"].astype('float')
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 2  18.0  female
# 3  19.4  female
# 4  20.0    male

# %%
#wrong convention converting original data to some other data 
df["Age"] = df["Age"].astype('int')
df
# Out:
#    Age  Gender
# 0   15    male
# 1   18  female
# 2   18  female
# 3   19  female
# 4   20    male

# %%
#observe original data is preserved
df["Age"] = df["Age"].astype('float')
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 2  18.0  female
# 3  19.0  female
# 4  20.0    male

# %%
#2. Duplicates:
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 2  18.0  female
# 3  18.0  female
# 4  20.0    male

# %%
df = pd.DataFrame({ "Age":
[15,18,18,19.4, 20], "Gender": ["male", "female", "female", "female", "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 2  18.0  female
# 3  19.4  female
# 4  20.0    male

# %%
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 2  18.0  female
# 3  19.4  female
# 4  20.0    male

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#     Age  Gender
# 2  18.0  female

# %%
df[~df.duplicated()]
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 3  19.4  female
# 4  20.0    male

# %%
#eliminate dulicated df.drop_duplicates()

# %%
df.drop_duplicates()
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 3  19.4  female
# 4  20.0    male

# %%
df=df.drop_duplicates(ignore_index=True)

# %%
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1  18.0  female
# 2  19.4  female
# 3  20.0    male

# %%
#Missing values:
df= pd.DataFrame({"Age": [15, np.nan, 24,19,20,22],
                  "Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1   NaN     NaN
# 2  24.0  female
# 3  19.0  female
# 4  20.0     NaN
# 5  22.0    male

# %%
df.isnull()
# Out:
#      Age  Gender
# 0  False   False
# 1   True    True
# 2  False   False
# 3  False   False
# 4  False    True
# 5  False   False

# %%
df.isnull().sum()
# Out:
# Age       1
# Gender    2
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# Age       16.666667
# Gender    33.333333
# dtype: float64

# %%
#df[condition]
df [df["Age"].isnull()]
# Out:
#    Age Gender
# 1  NaN    NaN

# %%
#recreate df to delete
df= pd.DataFrame({"Age": [15, np.nan, 24,19,20,22],
                  "Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1   NaN     NaN
# 2  24.0  female
# 3  19.0  female
# 4  20.0     NaN
# 5  22.0    male

# %%
df=[df.drop(index=[1])]

# %%
df
# Out:
# [    Age  Gender
#  0  15.0    male
#  2  24.0  female
#  3  19.0  female
#  4  20.0     NaN
#  5  22.0    male]

# %%
#recreate df to delete
df= pd.DataFrame({"Age": [15, df = pd.DataFrame({ "Age":
[15,18, "18",19.4, "20+"], "Gender": ["male", "female", "female", "female", "male"]})
df, 24,19,np.nan,22],
                  "Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1  10.0     NaN
# 2  24.0  female
# 3  19.0  female
# 4   NaN     NaN
# 5  22.0    male

# %%
#to know which insex values are null
df[df["Gender"].isnull()].index.to_list()
# Out:
# [1, 4]

# %%
df[df["Age"].isnull()].index.tolist()
# Out:
# [4]

# %%
##to drop any 1 row df df.drop(index=[1])
df=df.drop(index=[1,4])
df
# Out:
#     Age  Gender
# 0  15.0    male
# 2  24.0  female
# 3  19.0  female
# 5  22.0    male

# %%
df= pd.DataFrame({"Age": [15, np.nan, 24,19,np.nan,22],
                  "Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1   NaN     NaN
# 2  24.0  female
# 3  19.0  female
# 4   NaN     NaN
# 5  22.0    male

# %%
#remove rows which are missing values
df2= df.dropna()
df2
# Out:
#     Age  Gender
# 0  15.0    male
# 2  24.0  female
# 3  19.0  female
# 5  22.0    male

# %%
df1= df.drop(columns=["Gender"])
df1
# Out:
#     Age
# 0  15.0
# 1   NaN
# 2  24.0
# 3  19.0
# 4   NaN
# 5  22.0

# %%
df = pd.DataFrame({"Age":[15, np.nan, 24,19,20,22],
"Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1   NaN     NaN
# 2  24.0  female
# 3  19.0  female
# 4  20.0     NaN
# 5  22.0    male

# %%
df["Gender"].value_counts()
# Out:
# Gender
# male      2
# female    2
# Name: count, dtype: int64

# %%
df = pd.DataFrame({"Age":[15, np.nan, 24,19,20,22],
"Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1   NaN     NaN
# 2  24.0  female
# 3  19.0  female
# 4  20.0     NaN
# 5  22.0    male

# %%
# to fill with a value
df["Age"].fillna(20)
# Out:
# 0    15.0
# 1    20.0
# 2    24.0
# 3    19.0
# 4    20.0
# 5    22.0
# Name: Age, dtype: float64

# %%
df["Age"].mean()
# Out:
# 20.0

# %%
df = pd.DataFrame({"Age":[15, np.nan, 24,19,20,22],
"Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1   NaN     NaN
# 2  24.0  female
# 3  19.0  female
# 4  20.0     NaN
# 5  22.0    male

# %%
# to fill data statistically with mean
df['Age'].fillna (df["Age"].mean())
# Out:
# 0    15.0
# 1    20.0
# 2    24.0
# 3    19.0
# 4    20.0
# 5    22.0
# Name: Age, dtype: float64

# %%
df = pd.DataFrame({"Age":[15, np.nan, 24,19,20,22],
"Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df
# Out:
#     Age  Gender
# 0  15.0    male
# 1   NaN     NaN
# 2  24.0  female
# 3  19.0  female
# 4  20.0     NaN
# 5  22.0    male

# %%
df["Age"].median()
# Out:
# 20.0

# %%
## to fill data statistically with median

df=df['Age'].fillna(df["Age"].median())
df
# Out:
# 0    15.0
# 1    20.0
# 2    24.0
# 3    19.0
# 4    20.0
# 5    22.0
# Name: Age, dtype: float64

# %%
#mode will give multiple values where as mean and median give single value
df = pd.DataFrame({"Age":[15, np.nan, 24,19,20,22],
"Gender": ["male", np.nan, "female", "female", np.nan, "male"]})
df[ "Gender"].mode()
# Out:
# 0    female
# 1      male
# Name: Gender, dtype: object

# %%
df

# %%
df[ "Gender"].mode()[0]
# Out:
# 'female'

# %%
df["Gender"].fillna(df["Gender"].mode()[0])
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4    female
# 5      male
# Name: Gender, dtype: object
